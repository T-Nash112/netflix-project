# %% [markdown]
# # Netflix Titles Data Analysis
# ### Author: Nashtar Tshepang
#
# ## Objective
# Analyze Netflix movies and shows to uncover trends in production, ratings, genres, and global distribution.

# %% [markdown]
# ## Key Questions
# 1. How has Netflix content grown over time?
# 2. Are movies or shows more dominant?
# 3. What genres are most common?
# 4. Is there a relationship between IMDb and TMDB scores?
# 5. Which countries produce the most content?

# %% [markdown]
# ## Data Cleaning Summary
# - Filled missing text values (title, description, age_certification, imdb_id)
# - Left numeric ratings as NULL to preserve accuracy
# - Converted seasons to nullable integer (Int64)
# - Split genres and production countries into relational format

# %%
corr = df[['imdb_score', 'tmdb_score']].corr()
print(corr)

# %%
import matplotlib.pyplot as plt

plt.scatter(df['imdb_score'], df['tmdb_score'])
plt.xlabel("IMDb Score")
plt.ylabel("TMDB Score")
plt.title("IMDb vs TMDB Scores")
plt.show()

# %% [markdown]
# There is a positive correlation between IMDb and TMDB scores, indicating consistency in how content is rated across platforms.

# %%
titles_per_year = df['release_year'].value_counts().sort_index()

titles_per_year.plot()
plt.title("Content Growth Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.show()

# %%
type_year = df.groupby(['release_year','type']).size().unstack()

type_year.plot()
plt.title("Movies vs Shows Over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Content production has increased significantly over time, with shows growing rapidly in recent years compared to movies.

# %%
top_countries = prod_countries_df['production_countries'].value_counts().head(10)

top_countries.plot(kind='bar')
plt.title("Top 10 Production Countries")
plt.xlabel("Country")
plt.ylabel("Number of Titles")
plt.show()

# %% [markdown]
# A small number of countries dominate Netflix content production, indicating regional concentration of media industries.

# %%
genre_scores = genres_df.merge(
    df[['id','imdb_score']],
    on='id'
)

top_genres = genre_scores.groupby('genres')['imdb_score'].mean().sort_values(ascending=False).head(10)

top_genres.plot(kind='bar')
plt.title("Top Rated Genres")
plt.xlabel("Genre")
plt.ylabel("Average IMDb Score")
plt.show()

# %%
Certain genres consistently receive higher ratings, suggesting stronger audience engagement and quality perception.
